# %% [markdown]
# ## Import the Pickle

# %%
import pickle

pickle_tweets = open("C:/Users/Joris PC/Documents/Text Mining/Project/tweets_jan2019", "rb")
example_tweets = pickle.load(pickle_tweets)
example_tweets = example_tweets[["datetime","text"]]
#example_tweets["index1"] = example_tweets.index
example_tweets.head()
# Out:
#               datetime                                               text
# 0  2019-01-01 00:00:00  @ #1,  Bitcoin  with unit price of $3,742.7, m...
# 1  2019-01-01 00:00:00  Learn it. 2018 Sees  Bitcoin ’s Lowest Average...
# 2  2019-01-01 00:00:01  仮想通貨の時価総額  $125,622,003,150   BTC  価格:$3734.04...
# 3  2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
# 4  2019-01-01 00:00:01  Bitcoin  - BTC Price: $3,742.70 Change in 1h: ...

# %% [markdown]
# ### Take a sample

# %%
example_tweets = example_tweets.head(10000)

# %% [markdown]
# ### Dataframe to Dictionary

# %%
# create a dictionary out of the dataframe with two values -> datetime and text
tweet_dict = example_tweets.T.to_dict("list")
#tweet_dict

# %% [markdown]
# ### Detect Language

# %%
from langdetect import detect 
blanco = "blanco"

# Create a list saving all the languages of the tweets
language_list =[]
for i in tweet_dict:
    try:
        language = detect(tweet_dict[i][1])
        language_list.append(language)
    except:
        language_list.append(blanco)

# %%
print(set(language_list))
# Out:
# {'cs', 'af', 'hi', 'de', 'ca', 'et', 'da', 'pl', 'ro', 'tr', 'ru', 'es', 'id', 'nl', 'th', 'fi', 'blanco', 'pt', 'sl', 'no', 'mk', 'ja', 'he', 'sw', 'so', 'en', 'hr', 'tl', 'sq', 'vi', 'bg', 'zh-cn', 'ko', 'ar', 'fr', 'cy', 'it'}

# %%
example_tweets["Language"] = language_list

# %%
# Cut out all tweets which are not english
example_tweets = example_tweets.loc[example_tweets['Language'] == "en"]

# %%
tweet_dict = example_tweets.T.to_dict("list")

# %%
print(tweet_dict[0][1])
# Out:
# @ #1,  Bitcoin  with unit price of $3,742.7, market cap of $65,331,499,158 (52.01%), and 24 hr vol. of $4,661,840,806.32 (33.00%)

# %% [markdown]
# ### Preprocessing Tweets

# %%
import re
import string
for i in tweet_dict:
    y = tweet_dict[i][1]
    y = re.sub(r"@[A-Z-a-z-0-9_.]+","", y) #remove users with@
    #y=remove_emoji(y) #remove emojis
    #y = re.sub("(\:\)+|\=\)+|\:D+|(\:\(+|\=\(+|\:-\(+))"," ",y) #remove smiles not in unicode format
    y = y.replace("\n"," ") # remove enters
    y= re.sub(r"http\S+","",y) # removes links
    y= re.sub("\s+"," ",y)  #removes more one spaces
    y= re.sub(r"&(amp;)", "&", y) # removes and in html format
    #y = re.sub(r"[^\w\s]","",y) #remove special characters diferents languages, dot, questions marks, etc
    #y = re.sub(r"[^a-zA-Z\d\s:]","",y)
    y = re.sub(r"[0-9]","",y) #remove numbers
    y=re.sub(r"(.+?)\1+",r"\1",y) #remove repeted letters
    y= re.sub("\s+"," ",y) #remove more one space
    
    tweet_dict[i][1] = y   # overwrite the dictionary

# %%
import copy 
untoken_tweet_dict = copy.deepcopy(tweet_dict)

# %% [markdown]
# ### Tokenization & trimming of Tweets

# %%
from project_functions import *

# %%
# tokenization of the tweets

tweet_dict_token = tokenize_tw(tweet_dict)
print(tweet_dict_token[0][1])
# Out:
# ['bitcoin', 'with', 'unit', 'price', 'of', 'market', 'cap', 'of', 'and', 'hr', 'vol', 'of']

# %%
# remove stopwords of the tweets

tweet_dict_stopw = remove_stopwords(tweet_dict_token,"english")
print(tweet_dict_stopw[0][1])
# Out:
# ['bitcoin', 'unit', 'price', 'market', 'cap', 'hr', 'vol']

# %%
# Lemmatization of the tweets

tweet_dict_lemm = lemmatize(tweet_dict_stopw)
print(tweet_dict_lemm[0][1])
# Out:
# ['bitcoin', 'unit', 'price', 'market', 'cap', 'hr', 'vol']

# %%
# Stemmatization of the tweets

tweet_dict_stemm = stemmatize(tweet_dict_stopw, "english")
print(tweet_dict_stemm[0][1])
# Out:
# ['bitcoin', 'unit', 'price', 'market', 'cap', 'hr', 'vol']

# %% [markdown]
# ### Get the Sentiment TextBlob

# %%
from textblob import TextBlob

# %%
type(tweet_dict_lemm[0][1])
# Out:
# list

# %%
#define here which level of trimming you want to apply
tweets = tweet_dict_lemm
neutral = "neutral"
positive = "positive"
negative = "negative"

textblob_sentiment_list = []
for i in tweets:
    analyze = TextBlob(" ".join(tweets[i][1]))
    #print(analyze.polarity)
    if analyze.polarity == 0.0:
        textblob_sentiment_list.append(neutral)
    elif analyze.polarity > 0.0:
        textblob_sentiment_list.append(positive)
    elif analyze.polarity < 0.0:
        textblob_sentiment_list.append(negative)
    #textblob_sentiment_list.append(analyze.sentiment)

# %%
example_tweets["TextBlob_Sentiment"] = textblob_sentiment_list

# %%
example_tweets.head()
# Out:
#               datetime                                               text  \
# 0  2019-01-01 00:00:00  @ #1,  Bitcoin  with unit price of $3,742.7, m...
# 1  2019-01-01 00:00:00  Learn it. 2018 Sees  Bitcoin ’s Lowest Average...
# 3  2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
# 4  2019-01-01 00:00:01  Bitcoin  - BTC Price: $3,742.70 Change in 1h: ...
# 5  2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
#
#   Language TextBlob_Sentiment
# 0       en            neutral
# 1       en            neutral
# 3       en           positive
# 4       en           negative
# 5       en           positive

# %% [markdown]
# ### Get sentiment NLTK

# %% [markdown]
# The sentiment score of a text can be obtained by summing up the intensity of each word in the text and then normalizing it. The human raters of Vader used 5 heuristics to analyze the sentiment:
#
# * Punctuation — I love pizza vs I love pizza!!
# * Capitalization — I’m hungry!! vs I’M HUNGRY!!
# * Degree modifiers (use of intensifiers)— I WANT TO EAT!! VS I REALLY WANT TO EAT!!
# * Conjunctions (shift in sentiment polarity, with later dictating polarity) — I love pizza, but I really hate Pizza Hut (bad review)
# * Preceding Tri-gram (identifying reverse polarity by examining the tri-gram before the lexical feature— Canadian Pizza is not really all that great.
#
# ###### For that reason I didn't use the tokenized and cleaned dataset for this sentiment analysis
#
# https://towardsdatascience.com/https-towardsdatascience-com-algorithmic-trading-using-sentiment-analysis-on-news-articles-83db77966704
# http://datameetsmedia.com/vader-sentiment-analysis-explained/

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
# Out:
# C:\Users\Joris PC\Programming course\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
print(untoken_tweet_dict[0][1])
# Out:
# @ #, Bitcoin with unit price of $,., market cap of $, (.%), and hr vol. of $,. (.%)

# %%
NLTK_sentiment_list = []
neutral = "neutral"
positive = "positive"
negative = "negative"
tweet = untoken_tweet_dict

for i in tweet_dict:
    #print("Sentiment Score:", sia.polarity_scores(" ".join(tweets[i][1]))["compound"])
    if sia.polarity_scores(tweet[i][1])["compound"] == 0.0:
        NLTK_sentiment_list.append(neutral)
    elif sia.polarity_scores(tweet[i][1])["compound"] > 0.0:
        NLTK_sentiment_list.append(positive)
    elif sia.polarity_scores(tweet[i][1])["compound"] < 0.0:
        NLTK_sentiment_list.append(negative)

# %%
example_tweets["NLTK_Sentiment"] = NLTK_sentiment_list

# %%
example_tweets.head()
# Out:
#              datetime                                               text  \
# 0 2019-01-01 00:00:00  @ #1,  Bitcoin  with unit price of $3,742.7, m...
# 1 2019-01-01 00:00:00  Learn it. 2018 Sees  Bitcoin ’s Lowest Average...
# 3 2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
# 4 2019-01-01 00:00:01  Bitcoin  - BTC Price: $3,742.70 Change in 1h: ...
# 5 2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
#
#   Language TextBlob_Sentiment NLTK_Sentiment
# 0       en            neutral        neutral
# 1       en            neutral       negative
# 3       en           positive        neutral
# 4       en           negative        neutral
# 5       en           positive        neutral

# %% [markdown]
# ### Graph sentiment & BTC time series

# %%
example_tweets_graph = example_tweets

# %%
import pandas as pd
example_tweets_graph["datetime"] = pd.to_datetime(example_tweets_graph["datetime"])
example_tweets_graph = example_tweets_graph.set_index("datetime")
example_tweets_graph["hour"] = example_tweets_graph.index.hour

# %%
example_tweets_graph.head(1050)
# Out:
#                                                                   text  \
# datetime
# 2019-01-01 00:00:00  @ #1,  Bitcoin  with unit price of $3,742.7, m...
# 2019-01-01 00:00:00  Learn it. 2018 Sees  Bitcoin ’s Lowest Average...
# 2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
# 2019-01-01 00:00:01  Bitcoin  - BTC Price: $3,742.70 Change in 1h: ...
# 2019-01-01 00:00:01  IAM Platform Curated Retweet:  Via:  https:// ...
# 2019-01-01 00:00:01  Bitcoin ’s current exchange rate is 3734.52 US...
# 2019-01-01 00:00:01  You Suffer . . . But why !?  Bitcoin  just hit...
# 2019-01-01 00:00:01  Bitcoin  current price: 3742.32914528,change p...
# 2019-01-01 00:00:02  # cryptocurrency  Price Analysis for #Bitsend ...
# 2019-01-01 00:00:02  1 BTC = 14881.95932000 BRL em 31/12/2018 ás 22...
# 2019-01-01 00:00:02  Bitcoin @£3,157.97 | Ethereum@£115.15 | Liteco...
# 2019-01-01 00:00:02  01/01 09:00現在  #Bitcoin  : 404,785円↑ #NEM  #XE...
# 2019-01-01 00:00:02  Average  Bitcoin  market price is: USD 3,732.8...
# 2019-01-01 00:00:02  " Bitcoin  is the beginning of something great...
# 2019-01-01 00:00:03  A Russian  Bitcoin  mining grandmother is bull...
# 2019-01-01 00:00:03  MercadoBitcoin(BTC) => R$15394 | BlockChain(BT...
# 2019-01-01 00:00:03  BitcoinAverage -  bitcoin  price index - ($ 37...
# 2019-01-01 00:00:03  Make money even when  Bitcoin  is going down b...
# 2019-01-01 00:00:04  Dec 31, 2018 04:00PM #Bitcoin  Price: USD 3768...
# 2019-01-01 00:00:04  $ BTC  | #BTC  -  bitcoin 's Current Price: ▲ ...
# 2019-01-01 00:00:05  BTC,ETH,XRP Last: 3697.84, 131.35, 0.35 High: ...
# 2019-01-01 00:00:05  Free  Bitcoin  Mining earn without investing a...
# 2019-01-01 00:00:05  2019/01/01 09:00  BTC 406289円 ETH 14444.6円 ETC...
# 2019-01-01 00:00:07  Hey its the top of the hour time to beg mrbeas...
# 2019-01-01 00:00:07  One  Bitcoin  now worth $3736.963. Market Cap ...
# 2019-01-01 00:00:10  What percentage should you invest in each cryp...
# 2019-01-01 00:00:12  Bitcoin : Beyond The Bubble - Full Documentary...
# 2019-01-01 00:00:12                           Happy  Bitcoin  New Year
# 2019-01-01 00:00:12  Bitcoin , Ripple, Ethereum,  Bitcoin  Cash, EO...
# 2019-01-01 00:00:13  Last Month  Bitcoin  was: $4197.46, it is curr...
# ...                                                                ...
# 2019-01-01 01:15:46  Tone Vays Says  Bitcoin  Bull Run Will Leave C...
# 2019-01-01 01:15:49  Over 50% of populations cannot afford 1  Bitco...
# 2019-01-01 01:15:52  3 Reasons Why Cryptocurrency WILL Recover!  ht...
# 2019-01-01 01:15:55  Valuing  Bitcoin  in USD is ridiculous. Amazed...
# 2019-01-01 01:15:58  Bitcoin  Price Predictions 2019: What Experts ...
# 2019-01-01 01:16:00  I liked a @YouTube  video  http:// youtu.be/Bj...
# 2019-01-01 01:16:05  Lily Allen turned down 200K in Bitcoins for a ...
# 2019-01-01 01:16:07  Korea price Time: 01/01 10:16:10 BTC: 4,202,87...
# 2019-01-01 01:16:09  # bitcoin  Celebrities are back: Tony Robbins ...
# 2019-01-01 01:16:09  # bitcoin  This is problem for adoption. First...
# 2019-01-01 01:16:14  Happy New Year my #cryptocurrency  (#bitcoin )...
# 2019-01-01 01:16:18  Bitcoin , Ripple, Ethereum,  Bitcoin  Cash, EO...
# 2019-01-01 01:16:24                         Happy new year  Bitcoin .
# 2019-01-01 01:16:30  To be fair 2018 has been a shit show, let’s ho...
# 2019-01-01 01:16:30                                        Bitcoin !!!
# 2019-01-01 01:16:38  Tony Robbins Explains How  Bitcoin  Works to H...
# 2019-01-01 01:16:45  Tony Robbins Explains How  Bitcoin  Works to H...
# 2019-01-01 01:16:59  Missed 2 of 3 goals for 2018. Trading this yea...
# 2019-01-01 01:17:02  Order your secure and smart BTC/ETH/Altcoin ha...
# 2019-01-01 01:17:04  Correction: continue to fail. Since he said  B...
# 2019-01-01 01:17:07  Bitcoin  Cash BCH Current Price: $153,693 1 Ho...
# 2019-01-01 01:17:07  XRP A Better Bet Than  Bitcoin  Despite Centra...
# 2019-01-01 01:17:08  Bitcoin  Adoption Could Be Boosted By Surging ...
# 2019-01-01 01:17:21  You retired because of  Bitcoin  profits? Supe...
# 2019-01-01 01:17:23  Bitcoin  Premier early #Airdrop  Bot   Bitcoin...
# 2019-01-01 01:17:25  Venture capitalist Lou Kerner says  bitcoin  i...
# 2019-01-01 01:17:36  Chainging Money - A piece in the Money Chainge...
# 2019-01-01 01:17:37  I think it really will be a HappyNewYear Alex....
# 2019-01-01 01:17:45  Bitcoin  Could Revolutionize Governance, Says ...
# 2019-01-01 01:17:46  LOVE!!AndorraWe hope to help, thank you.  / bi...
#
#                     Language TextBlob_Sentiment NLTK_Sentiment  hour
# datetime
# 2019-01-01 00:00:00       en            neutral        neutral     0
# 2019-01-01 00:00:00       en            neutral       negative     0
# 2019-01-01 00:00:01       en           positive        neutral     0
# 2019-01-01 00:00:01       en           negative        neutral     0
# 2019-01-01 00:00:01       en           positive        neutral     0
# 2019-01-01 00:00:01       en            neutral       positive     0
# 2019-01-01 00:00:01       en            neutral       negative     0
# 2019-01-01 00:00:01       en            neutral        neutral     0
# 2019-01-01 00:00:02       en           negative        neutral     0
# 2019-01-01 00:00:02       en            neutral        neutral     0
# 2019-01-01 00:00:02       en            neutral        neutral     0
# 2019-01-01 00:00:02       en            neutral        neutral     0
# 2019-01-01 00:00:02       en            neutral        neutral     0
# 2019-01-01 00:00:02       en           positive       positive     0
# 2019-01-01 00:00:03       en            neutral        neutral     0
# 2019-01-01 00:00:03       en            neutral        neutral     0
# 2019-01-01 00:00:03       en            neutral        neutral     0
# 2019-01-01 00:00:03       en           positive       positive     0
# 2019-01-01 00:00:04       en            neutral        neutral     0
# 2019-01-01 00:00:04       en            neutral        neutral     0
# 2019-01-01 00:00:05       en           positive       negative     0
# 2019-01-01 00:00:05       en            neutral       negative     0
# 2019-01-01 00:00:05       en            neutral        neutral     0
# 2019-01-01 00:00:07       en           positive       positive     0
# 2019-01-01 00:00:07       en           negative       positive     0
# 2019-01-01 00:00:10       en            neutral        neutral     0
# 2019-01-01 00:00:12       en            neutral        neutral     0
# 2019-01-01 00:00:12       en           positive        neutral     0
# 2019-01-01 00:00:12       en            neutral        neutral     0
# 2019-01-01 00:00:13       en            neutral        neutral     0
# ...                      ...                ...            ...   ...
# 2019-01-01 01:15:46       en            neutral       positive     1
# 2019-01-01 01:15:49       en            neutral        neutral     1
# 2019-01-01 01:15:52       en            neutral       positive     1
# 2019-01-01 01:15:55       en            neutral       positive     1
# 2019-01-01 01:15:58       en            neutral        neutral     1
# 2019-01-01 01:16:00       en            neutral       positive     1
# 2019-01-01 01:16:05       en           positive       positive     1
# 2019-01-01 01:16:07       en            neutral        neutral     1
# 2019-01-01 01:16:09       en            neutral       positive     1
# 2019-01-01 01:16:09       en           positive       negative     1
# 2019-01-01 01:16:14       en           positive        neutral     1
# 2019-01-01 01:16:18       en            neutral        neutral     1
# 2019-01-01 01:16:24       en           positive        neutral     1
# 2019-01-01 01:16:30       en           positive       positive     1
# 2019-01-01 01:16:30       en            neutral        neutral     1
# 2019-01-01 01:16:38       en            neutral        neutral     1
# 2019-01-01 01:16:45       en            neutral        neutral     1
# 2019-01-01 01:16:59       en            neutral       positive     1
# 2019-01-01 01:17:02       en           positive       positive     1
# 2019-01-01 01:17:04       en           negative       negative     1
# 2019-01-01 01:17:07       en            neutral        neutral     1
# 2019-01-01 01:17:07       en            neutral        neutral     1
# 2019-01-01 01:17:08       en            neutral       negative     1
# 2019-01-01 01:17:21       en           positive       positive     1
# 2019-01-01 01:17:23       en            neutral       negative     1
# 2019-01-01 01:17:25       en            neutral       positive     1
# 2019-01-01 01:17:36       en           positive        neutral     1
# 2019-01-01 01:17:37       en            neutral       positive     1
# 2019-01-01 01:17:45       en            neutral        neutral     1
# 2019-01-01 01:17:46       en           positive       positive     1
#
# [1050 rows x 5 columns]

# %%
pnn_counts_textblob = example_tweets_graph.groupby(["hour", "TextBlob_Sentiment"])["text"].count()
pnn_counts_textblob = pnn_counts_textblob.to_frame()
pnn_counts_textblob = pnn_counts_textblob.reset_index()
pnn_counts_textblob = pnn_counts_textblob.rename(columns= {"text":"textblob_count"})

pnn_counts_nltk = example_tweets_graph.groupby(["hour", "NLTK_Sentiment"])["text"].count()
pnn_counts_nltk = pnn_counts_nltk.to_frame()
pnn_counts_nltk = pnn_counts_nltk.reset_index()
pnn_counts_nltk = pnn_counts_nltk.rename(columns= {"text":"nltk_count"})

# %%
textblob_count = pnn_counts_textblob["textblob_count"].tolist()
pnn_counts_nltk["textblob_count"] = textblob_count

pnn_counts = pnn_counts_nltk
pnn_counts = pnn_counts.rename(columns= {"NLTK_Sentiment":"sentiment"})
pnn_counts.head(9)
# Out:
#    hour sentiment  nltk_count  textblob_count
# 0     0  negative         122              63
# 1     0   neutral         437             495
# 2     0  positive         252             253
# 3     1  negative          98              72
# 4     1   neutral         359             426
# 5     1  positive         231             190
# 6     2  negative          90              82
# 7     2   neutral         394             422
# 8     2  positive         210             190

# %%
import seaborn as sns
fig, ax = plt.subplots(1,2, figsize=(45,15))
sns.lineplot(x="hour", y="textblob_count", hue="sentiment", data=pnn_counts, ax=ax[0])
sns.lineplot(x="hour", y="nltk_count", hue="sentiment", data=pnn_counts, ax=ax[1])
#plt.legend(loc="upper left")
