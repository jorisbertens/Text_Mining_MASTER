# %%
import pandas as pd

# %%
df = pd.read_csv("test_set_4000.csv", sep=";")
df_marius = df.iloc[:1001]
df_luis = df.iloc[1001:2001]
df_alex = df.iloc[2001:3001]
df_joris = df.iloc[3001:]

# %%
df_joris = df_joris[["SENTIMENT", "1"]]

# %%
df_joris
# Out:
#      SENTIMENT                                                  1
# 3001       NaN  A new post: XLM Price Returns to $0.11 as Sato...
# 3002       NaN  Local Media: Iran Reportedly in Talks With 8 C...
# 3003       NaN  Bitcoin  Price Will Tank to ‘Zero’, Claims Inv...
# 3004       NaN  $ BTC  is playing in the same channel for quit...
# 3005       NaN  Nobody is forcing them to accept  bitcoin . If...
# 3006       NaN  Bitcoin  Price Holds $4K As One Transaction Se...
# 3007       NaN  # Securypto  is a great & promising project th...
# 3008       NaN  Iran lifts ban on #Bitcoin  and now recognizes...
# 3009       NaN  NYDFS Grants BitLicense to Third  Bitcoin  ATM...
# 3010       NaN                 Candle to 4K then plummets to 3.3k
# 3011       NaN  Seed CX Launches  Bitcoin  Spot Trading Market...
# 3012       NaN  Chimpion is partnering with  Bitcoin  Diamond ...
# 3013       NaN  Crypto Daily Exclusive! An Interview With ECC ...
# 3014       NaN  JPMorgan & Chase: Only Low-Cost Chinese  Bitco...
# 3015       NaN  The Hardware  Bitcoin  Wallet. Get Trezor now ...
# 3016       NaN  “As technology advances, we can either shape i...
# 3017       NaN  One  Bitcoin  now worth $3558.32@bitstamp. Hig...
# 3018       NaN  Nice! I found a new Free  Bitcoin  Faucet! Get...
# 3019       NaN  WBTC ontop of Ethereum is like Ethereum winnin...
# 3020       NaN  New post ( Bitcoin  Price Analysis: Major Supp...
# 3021       NaN  Crypto is the #future .  But only if we collec...
# 3022       NaN  Bitcoin  and Crypto Analysts 'Smoking Fairy Du...
# 3023       NaN  You're not wrong. But someone like Saife is an...
# 3024       NaN  01/16 17:00現在  #Bitcoin  : 389,650円↓ #NEM  #XE...
# 3025       NaN  Why Apollo Currency (APL) Did Not Dump or ‘Exi...
# 3026       NaN  you didn't understand. bitcoiners won't sell  ...
# 3027       NaN  # QuarkChain  #Blockchain  #sharding  #Crypto ...
# 3028       NaN  Traders: If  Bitcoin  Price Fails to Remain Ab...
# 3029       NaN  51% attacks happen rarely because they‘re not ...
# 3030       NaN  Buy GHT token here:  https://www. etherflyer.c...
# ...        ...                                                ...
# 4015       NaN  Hacker group threatens to leak 9/11 ‘truth’ un...
# 4016       NaN  https:// bitcoinist.com/gdpr-privacy-b rave-ep...
# 4017       NaN  Down More than 70% in 2018,  Bitcoin  Closes I...
# 4018       NaN  Indian Supreme Court Pushes Crypto Case Agains...
# 4019       NaN  CCN:  Bitcoin  Can Be Worth a Lot or Zero: Mon...
# 4020       NaN  @ DMM_ Bitcoin   こんなことしてDMM誰が使うねん    https:// ...
# 4021       NaN  And you get a side effect GDP boost afterwards...
# 4022       NaN  Kripto Para ATM’leri Artıyor =>  https:// coin...
# 4023       NaN  # SHORT  played out - BIG PROFIT thanks to #ma...
# 4024       NaN  Uptown Aces Casino $10 Free Chip for New Playe...
# 4025       NaN  Bitcoin ’s 292,000 Daily Wikipedia Hits Shows ...
# 4026       NaN  $6AX:GR - Press Release - the ability to succe...
# 4027       NaN  You are stronger than you think. #success  #Mo...
# 4028       NaN                     Can you do same for  Bitcoin ?
# 4029       NaN  The current price of  Bitcoin  is $3543.087710...
# 4030       NaN  rBitcoins  : I made a service that implements ...
# 4031       NaN  Advantages of Bit World for traders:  1. Build...
# 4032       NaN  Slant Launched to Enable data Privacy via Bloc...
# 4033       NaN  NEW DATES  NEW UPGRADES      #P2PGlobalNetwrok...
# 4034       NaN  Looking North?  Bitcoin  Price Dip Forms Bull ...
# 4035       NaN  Why the name floated over the branches were lo...
# 4036       NaN  Should You Set Yourself Daily Targets In Forex...
# 4037       NaN  Yes, some XRP, ETH etc. mocking is real. It's ...
# 4038       NaN  # cryptocurrency  #bitcoin  #crypto  #blockcha...
# 4039       NaN  @ Quickxprotocol  creates bond with other mult...
# 4040       NaN  New Research Exposes Anti- Bitcoin  Bias in a ...
# 4041       NaN  Bitcoin , Ripple, Ethereum, EOS,  Bitcoin  Cas...
# 4042       NaN  All You Need To Know About  Bitcoin   https://...
# 4043       NaN  Get $25 in  Bitcoin  for signing up to Voyager...
# 4044       NaN  01/28 19:00現在  #Bitcoin  : 375,970円↑ #NEM  #XE...
#
# [1044 rows x 2 columns]
