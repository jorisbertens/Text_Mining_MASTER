# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import sentiment_mod as s
from textblob import TextBlob

# %% [raw]
# def sentiment_textblob(text):
#     analyze = TextBlob(text)
#
#     if analyze.polarity == 0.0:
#         return "neutral", analyze.polarity
#         #textblob_sentiment_list.append(neutral)
#     elif analyze.polarity > 0.0:
#         return "positive", analyze.polarity
#         #textblob_sentiment_list.append(positive)
#     elif analyze.polarity < 0.0:
#         return "negative", analyze.polarity
#         #textblob_sentiment_list.append(negative)
#
#     def on_data(self, data):
#         all_data = json.loads(data)
#
#         tweet = all_data["text"]
#         sentiment_value, polarity = sentiment_textblob(tweet)
#         print((tweet, sentiment_value, polarity))
#
#         return True

# %%
ckey = ""
csecret = ""
atoken = ""
asecret = ""

class listener(StreamListener):
    
    def on_data(self, data):
        all_data = json.loads(data)
        
        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)     
        print((tweet, sentiment_value, confidence))
        
        if confidence*100 >=70:
            output = open("twitter-out.txt", "a")
            output.write(sentiment_value)
            output.write("\n")
            output.close()
            
        return True
    
    def on_error(self, status):
        print(status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["bitcoin"])
# Out:
# ('@CNBC #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/35v7T9j7qq', 'pos', 0.7142857142857143)
# ('@QuorraMarket @electroneum #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('RT @CashaaLtd: Today is the day we are launching our #business plans! Whether you are an #unbanked #crypto business or looking for the best…', 'neg', 1.0)
# ('Lightning Network-Powered Bitcoin Exchange Sparkswap Goes Live with Public Beta https://t.co/eWbpNMykMa #bitcoin… https://t.co/aaCXDlX1nh', 'neg', 1.0)
# ('@CoinDeskMarkets #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/BgINiMluzP', 'pos', 0.7142857142857143)
# ('@Reuters #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ('@CharlieBitbuy @jack @MargaretAtwood #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@aaron_hogan @katiemartinedu #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('RT @Swiss_Satoshi: We’re happy we just received our second crypto payment solution to accelerate mass adoption of cryptocurrencies in Switz…', 'pos', 1.0)
# ('@Trudy13702984 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('RT @SARUMAN1: Alguien sabe q pasó con "aquellos muchachos" a quienes les dieron muchos dólares para traer máquinas para minería de Criptomo…', 'neg', 0.8571428571428571)
# ('@BobLoukas #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('@AliceMcCloskey2 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/SDjohtlhOv', 'pos', 0.7142857142857143)
# ("RT @iulian_neagoe: From BTC Price To Musk's Reign as Dogecoin CEO: Top Stories From The Past Week https://t.co/Iw8lOJgcaX #Blockchain #bitc…", 'neg', 1.0)
# ('@DollarVigilante #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1me9lfSnJZ', 'pos', 0.7142857142857143)
# ('@JamesTodaroMD #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('RT @crypto__mak: Online Bank Mistertango Offers Crypto Companies Multiple Accounts and Ibans https://t.co/QGQsai42y0 #Bitcoin #Exchanges #c…', 'neg', 1.0)
# ('@BankXRP #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/SDjohtlhOv', 'pos', 0.7142857142857143)
# ('RT @ICOAnnouncement: 🎙 New Featured Project\n                    \n🔷 Bitcoin Oil (BTCO)\n\n🔶 Bitcoin Oil is a hard fork of Bitcoin, with improv…', 'neg', 1.0)
# ('@Schuldensuehner #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('Bitcoin value: $5209.57', 'neg', 1.0)
# ('@alistairmilne #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@realLudvigArt #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('Dow Jones\nS&amp;P 500 \nNasdaq\n10 Year Treasuries\n.\n.\n.\nBitcoin!', 'neg', 1.0)
# ('@WomanBlockchain @Radioactive3D @bitninjasupply @womeninblockch3 @Coinboyspodcast @D_Kevs @mysticaloaks… https://t.co/cbNDW2yLGC', 'neg', 1.0)
# ('RT @crypto__mak: Responding to The Motley Fool’s Anti-Bitcoin Article https://t.co/ySShzM3ssN #Bitcoin #Cryptocurrency', 'neg', 0.5714285714285714)
# ('@xtdisnkfe #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ('@StayDashy @DiscoverDash @Dashpay #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('@PeterMcCormack @Snyke #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/SDjohtlhOv', 'pos', 0.7142857142857143)
# ('@C_ScareCrow_H @NoHolyScripture @SkepticNikki @timberners_lee @vgcerf Nobody rules Bitcoin. It is the end of rulers.', 'neg', 1.0)
# ('#HIGH #HighBank #ICO #Bitcoin #Ethereum #Cryptocurrency \nJust visit the medium pager and see update https://t.co/kcuR27LGhe', 'pos', 0.8571428571428571)
# ('@freebitco #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/35v7T9j7qq', 'pos', 0.7142857142857143)
# ('RT @tron_squad: ❤️ https://t.co/I2269kOKhy', 'neg', 1.0)
# ('@alexmejias @CasaHODL @TraceMayer #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@cryptobubbly #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('@RichMartel How can you otherwise ever agree upon a protocol when you can just keep on voting until the end of time… https://t.co/CILoCUgYgW', 'pos', 0.5714285714285714)
# ('@krugermacro #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xrapjkhdLg', 'pos', 0.7142857142857143)
# ('Follow my #SnapChat! - WokeChain\n\nFor that.... Inside info. 😉🙃🚀\n\n#crypto #Bitcoin #cryptohumor #cryptocomedy #HODL… https://t.co/8Y9qBDU5lf', 'neg', 1.0)
# ('@barrysilbert @markets #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@RodrigoThirry #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ('RT @maxkeiser: Agree!!! And the new global financial crisis is underway.  \n\nObama’s Chief of Staff Says #Bitcoin Adoption Inevitable in Fin…', 'neg', 0.5714285714285714)
# ('@Torosushi2 @PundiXLabs #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@Hipster_Trader #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/BgINiMluzP', 'pos', 0.7142857142857143)
# ('@lopp @LukeDashjr #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@zynecoin #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('Top 5 Countries Where Google Searches for Bitcoin Just Tripled https://t.co/yiLT7kviZS', 'neg', 1.0)
# ('The Game Is On For #Bitcoin, #Ethereum, #Ripple And #Litecoin via @forbes https://t.co/9aGT3gZJZ6', 'neg', 1.0)
# ('@martik @APompliano @JWilliamsFstmed #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('More than 20% of Bitcoin shorts were closed on Bitfinex https://t.co/nh4eQGOo9U https://t.co/NqMvo7gAQW', 'neg', 1.0)
# ('@FinancialTimes #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/BgINiMluzP', 'pos', 0.7142857142857143)
# ('@JWilliamsFstmed #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/35v7T9j7qq', 'pos', 0.7142857142857143)
# ('@tradingroomapp #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@SmokeyXBT #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Ycf22NHdaq', 'pos', 0.7142857142857143)
# ('@100trillionUSD #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('RT @Daman___: Highlights: The Internet of Money - Volume 2\n#bitcoin #BTC\n\nhttps://t.co/8OlWy2sb3v\nvia \n@youtube https://t.co/l1GbyA6Ceo', 'neg', 1.0)
# ('RT @RedKatLife: Top 5 Countries Where Google Searches for #Bitcoin Just Tripled 📈\n\nThe Rundown\n1. Nigeria 🇳🇬 \n2. Netherlands 🇳🇱 \n3. South A…', 'neg', 1.0)
# ('@TheStalwart #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('Bitcoin and Friends - ビットコインのカートゥーン - https://t.co/sM7enTwoiI', 'neg', 1.0)
# ('Bitcoin and Friends - ビットコインのカートゥーン - https://t.co/idBr4Fh9GM', 'neg', 1.0)
# ('Bitcoin and Friends - ビットコインのカートゥーン - https://t.co/9NYrLLImem', 'neg', 1.0)
# ('RT @iamjosephyoung: Looks like some people are interested in bitcoin https://t.co/ERt2XJsry2', 'neg', 1.0)
# ('@BitcoinRh @Trezor #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('@WhalePanda #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/35v7T9j7qq', 'pos', 0.7142857142857143)
# ('New Bitcoin ATM Machine in Essex!\n\n #crypto #ripple #xrp #hold #verge #xvg #btc #bitcoin #cryptocurrency… https://t.co/66GkqhXOfa', 'neg', 1.0)
# ('RT @SARUMAN1: Alguien sabe q pasó con "aquellos muchachos" a quienes les dieron muchos dólares para traer máquinas para minería de Criptomo…', 'neg', 0.8571428571428571)
# ('@wellstoken #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('@alistairmilne #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/BgINiMluzP', 'pos', 0.7142857142857143)
# ('Bitcoin azıcık toparlandı diye resort otelde kalmak biraz şov bence :))\nEs kaza 10K falan olsa; viuuuuu, hobaaaaa,… https://t.co/DLt34kwPfF', 'neg', 1.0)
# ('@business @EdVanDerWalt #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@IDAXpro #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ('@TheCryptoLark #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xrapjkhdLg', 'pos', 0.7142857142857143)
# ("RT @CoinCorner: Banking has always been challenging for #bitcoin exchanges, so we're VERY excited to announce that we've secured a UK bank…", 'pos', 1.0)
# ('@hodlonaut #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/BgINiMluzP', 'pos', 0.7142857142857143)
# ('@FrontHedge #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('@Bull0fBitcoin #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ("RT @truegameSRL: He predicted #BTC's 2018 plunge. 📉 \nNow he predicts #Bitcoin to reach $50,000 within two years. 📈\nHow tempting is it to be…", 'neg', 0.7142857142857143)
# ('@CryptoBac #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xrapjkhdLg', 'pos', 0.7142857142857143)
# ('@CryptoNekoZ @JBTheCryptoKing 1. EXRN / EXRT tech revolution , hidden gem , under the radar\n2. Bitcoin\n3. Ethereum', 'neg', 0.5714285714285714)
# ('@crypto #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('Options Finally Come to Ethereum and Bitcoin\n#pumpanddump #binance #IoT #buyorders #FUD #coldstorage #premining… https://t.co/QowhsGwA6n', 'neg', 1.0)
# ('RT @CoinCasso: #TEAMZSummit2019, organised by @teamz_inc!  🇯🇵\n💎"https://t.co/ql9j0cKHiw is very happy to be here at the TEAMZ Blockchain Su…', 'pos', 0.5714285714285714)
# ('@crypto_rand #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xrapjkhdLg', 'pos', 0.7142857142857143)
# ('@_Crypto_Maniac_ #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@crypto #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xrapjkhdLg', 'pos', 0.7142857142857143)
# ('@krakenfx #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@C3_Nik @coinbase #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/BgINiMluzP', 'pos', 0.7142857142857143)
# ('RT @Litecoinoffici1: #EnterToWin Up To 39.6 #Litecoin ! #ltc\n\nNever Miss A Chance To Win $LTC!\n\nEnter DAILY👇\n#bitcoin\n✅ Follow us\n✅ Retweet…', 'neg', 1.0)
# ('@TheBitfi #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('5 стран, в которых "Bitcoin" стали искать намного чаще. Статистика от Google - О криптовалютах, майнинге и трейдинг… https://t.co/YHpUGp4wv3', 'neg', 1.0)
# ('@jeetsidhu_ #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('@RayDalio @60Minutes Scrap easy money policies, roll back all government interventionism in the markets, let the fr… https://t.co/a0zr6xbu2W', 'neg', 1.0)
# ('@BTCMarkets #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/1bqMOdDZeZ', 'pos', 0.7142857142857143)
# ('Dollar Will Be Replaced By Gold And Bitcoin By 2040 – Robert Kiyosaki - Make money online!: https://t.co/OvJ79DgEJy', 'neg', 0.7142857142857143)
# ('@brotherach @DAPScoin #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('Chinese Crypto Investors Return Strongly In Bitcoin: Did They Cause BTC Surge? https://t.co/n0blgbmoL8', 'neg', 1.0)
# ('@iamjosephyoung #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/tJVbY8knT1', 'pos', 0.7142857142857143)
# ('@CoinsDaddy #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ('buy cash online https://t.co/GoCAgkWOCs #how do i get a bitcoin for free', 'neg', 1.0)
# ('@johnkim77 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@tranhung30891 @trannam1992 @Tranhunghdtv @MinhNd1111 @nguyenhoangvk', 'neg', 1.0)
# ('Pantera Leads $3.5 Million Round for Lightning-Powered SparkSwap DEX Pantera-backed SparkSwap has launched to offer… https://t.co/y8fMVC5RDy', 'neg', 1.0)
# ('Chinese Crypto Whales Avoid Ban with Premium OTC Trading to Buy Bitcoin https://t.co/VOV7O30w6z via → https://t.co/K00F7fwtRe', 'neg', 1.0)
# ('#top #5 #countries where #google #searches for #bitcoin just #tripled \n#instabitcoin #instacrypto #instaeth… https://t.co/DPpq2Ngn6p', 'neg', 1.0)
# ('Top 5 Countries Where Google Searches for Bitcoin Just Tripled https://t.co/H6m8jaNHz1 via → https://t.co/K00F7fwtRe', 'neg', 1.0)
# ('@CryptoPricePre1 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('Samsung Default Crypto, TRON x Ethereum Collaboration, Ethereum Classic Surge &amp; Media Loves Bitcoin… https://t.co/p6AQ3ondyf', 'neg', 1.0)
# ('@wavesplatform #Waves #wavesplatform #web30 #blockchain #developers #bitcoin', 'neg', 1.0)
# ('XRP More Popular than Bitcoin? QuarkChain Explained, TomoChain Partnership, Binance Giveaway https://t.co/9qSvLcbotT https://t.co/lDo5tjBYDd', 'neg', 1.0)
# ('@Crypto_Tone1 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@manianban #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xrapjkhdLg', 'pos', 0.7142857142857143)
# ('RT @SchiemerMktng: The Facts You Need To Know Before Investing In Bitcoin And Crypto https://t.co/QvXrO6DFXE / #Bitcoin #Crypto #Blockchain…', 'neg', 1.0)
# ('@AlexSaundersAU #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/xfV8YIC9Az', 'pos', 0.7142857142857143)
# ('Crypto Panic: Bitcoin transactions per block at all-time highs https://t.co/FjF8vrHzTZ 🙋Crypto Cashflow via →… https://t.co/uQpHnT11OT', 'neg', 0.8571428571428571)
# ("HSBC suspends pensioner's transaction to buy Bitcoin; flags it 'suspicious' https://t.co/QAFDwRWPpo via → https://t.co/K00F7fwtRe", 'neg', 1.0)
# ('@johnkim77 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/5KRGgDfGtQ', 'pos', 0.7142857142857143)
# ('RT @StayDashy: #Bitcoin block reward decreases 50% every 4 years.\nNext reduction ETA: Sunday 23rd May 2020.\n\n#Dash block reward decreases b…', 'neg', 1.0)
# ('RT @btc_green: Did you know #Bitcoin consumes as much energy as a large country? \n\nBitcoin Green is energy-efficient and easy to mine with…', 'pos', 0.5714285714285714)
# ('@VNumeris @TravelbyBit @walletofsatoshi #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@10altcoins #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@gaborgurbacs @justinsuntron @Tronfoundation @BitTorrent #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@danheld #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@Mangofiend #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('RT @Josh_Rager: Could be another slight pullback for $BTC\n\nBut Bitcoin has been putting up higher-lows for the past week https://t.co/VdETG…', 'neg', 1.0)
# ('@danheld #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@AskMeHowToShort #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@pannchoa #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@StopAndDecrypt #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@DJ_Erock23 @jkaartinen @brian_trollz @mj4m1n @nvk @SauceryCoin @LukeDashjr @giacomozucco @BitcoinTina @andhans… https://t.co/5d5nFTnCLD', 'neg', 1.0)
# ('@LuchoPoletti @LynxCollection @CryptoBrekkie @SanityCrypto @bitninjasupply @Bitboy_Hodl @ShitcoinSherpa @BLK_ART_… https://t.co/xG45G07wrY', 'neg', 1.0)
# ('@SickRick727 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@sajmathieu #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@OneMorePeter #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@cloakcoin_promo @CloakCoin @monero @zcashco #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('The Pirate Bay gets it\n\n👉 https://t.co/NLEn6DitPh 👀\n\nRegister Now &amp; Start Buying📈 &amp; Selling📉 Cryptocurrency ✅… https://t.co/wxwz2snFZE', 'neg', 1.0)
# ('RT @jpthor__: If you think your coffee $2 transaction has as much importance as a $2bn on-chain censorship-resistant settlement, then you d…', 'neg', 1.0)
# ('@C_Broadus21 #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/Bp6jkNa6eW', 'pos', 0.7142857142857143)
# ('@cryptotradersfa #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('@TraceMayer @bitstein @francispouliot_ @TuurDemeester @pierre_rochard @APompliano @theonevortex @ToneVays @jespow… https://t.co/AsjCDD1vFM', 'neg', 1.0)
# ('RT @coinairdropall: #Bitcoin #Satoshi #crypto #blockchain #Airdrop\nNew Airdrop #Griffex 📢\n\nGriffex is airdropping up to 9400 #GFX to their…', 'neg', 1.0)
# ('@youngdumbcrypto #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ("💰💫#HIZLIBET'TEN ÇEVRİMSİZ BONUS YAĞMURU!\n\n💰💫#PAPARA İLE  20₺ YATIR! %25 #CEVRİMSİZ BONUS AL!\n\n💰💫#BITCOIN İLE  20₺ Y… https://t.co/gwnA0WRj6C", 'neg', 1.0)
# ('@galaxyBTC #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('RT @danheld: Bitcoin raised $0 to become the internet of money.', 'neg', 1.0)
# ('@100trillionUSD #btc #bitcoin New crypto-bot, daily profit under 15%, link: https://t.co/ld4KW3n77j', 'pos', 0.7142857142857143)
# ('RT @tron_squad: ❤️❤️❤️😇😇😇🌝🌝🌝 https://t.co/p01F6xQHwQ', 'neg', 1.0)
# ('@TheRealXinxi Not surprised! 👍\n\nhttps://t.co/ccvMTyhymA', 'pos', 1.0)
# ('RT @bitwala: #BTCUSD Market Watch: Does this look familiar to you?  \nFind out more: https://t.co/jnH8F0MdzK #trading #bitcoin #crypto https…', 'neg', 1.0)
# ('RT @ICOAnnouncement: 🎙 New Featured Project\n                    \n🔷 Bitcoin Oil (BTCO)\n\n🔶 Bitcoin Oil is a hard fork of Bitcoin, with improv…', 'neg', 1.0)
# ('RT @Dikastiko_gr: Στις 11 Απριλίου συνεχίζεται η «μάχη» για το Mr\xa0Bitcoin https://t.co/kFELQQGqoa https://t.co/spH8Dbz3RV', 'neg', 1.0)
# ('$btc #bitcoin\n\n#SignalFI https://t.co/nNojwl7XG5', 'neg', 1.0)
# ('Pantera Leads $3.5 Million Round for Lightning-Powered SparkSwap DEX https://t.co/Hdu0JDAmsP #Bitcoin $BTC', 'neg', 1.0)
# ('#Litecoin #LTC #LitecoinFam #Bitcoin #BTC #Crypto', 'neg', 1.0)
# ('RT @whale_alert: 708 #BTC (3,673,121 USD) transferred from #Kraken to unknown wallet\n\nTx: https://t.co/tgujd4W1oy', 'pos', 1.0)
# ('笑笑はつねに投資先の開発と確認を行っている #bitcoin #onacoin #dogecoin', 'neg', 1.0)
# ('RT @coindesk: JUST IN: Pantera-backed @sparkswap has launched to offer pro traders litecoin-to-bitcoin atomic swaps using the lightning net…', 'neg', 1.0)
# ('RT @maxkeiser: All this talk about Fed needing to lower rates has money pouring into #Bitcoin as a safe haven. Gold is also looking like it…', 'neg', 0.7142857142857143)
# ('CriptoNoticias: Bitcoin supera los USD 5.200 y pocas altcoins lo acompañan https://t.co/jaSjVrtENl', 'pos', 1.0)
# ("RT @swissborg: Listen to @TraderCobb's interview with @Cyrus_Fazel, our founder, about the future of #finance, #SwissBorg's #ICO, Community…", 'neg', 1.0)
# ('At the Blockchain Africa Conference in 2019, we saw how important blockchain is in developing communities and tackl… https://t.co/4Y1FLhYtEP', 'neg', 0.8571428571428571)
# ('#Waves #wavesplatform #web30 #blockchain #developers #bitcoin', 'neg', 1.0)
# ('RT @Airdropnotecom: #Bitcoin #Satoshi #crypto #blockchain #Airdrop\nNew Airdrop #GOZO 📢\n\nReward : Free 1150 #Gozo Tokens ✈️💰\n\nRefer Reward :…', 'neg', 1.0)
# ('RT @TheBlock__: Sparkswap raises $3.5M to build an exchange on the Bitcoin Lightning Network (via @Dogetoshi)\nhttps://t.co/ZvjwLEpZ7Y', 'neg', 0.7142857142857143)
# ('South Korean police use AI to bust $19M Bitcoin-fuelled pyramid scam \nSouth Korean police have caught the mastermin… https://t.co/ACBjW4SeDx', 'neg', 0.8571428571428571)
# ('RT @recursosbitcoin: El precio del bitcoin es de US$ 5202.37. #bitcoin #btc', 'pos', 0.5714285714285714)
# ('Hedging bitcoin with other financial assets https://t.co/jB8axE7tSu', 'neg', 1.0)
# ('RT @MyHEdpAY: bid buy and win hdp @KangaExchange https://t.co/BVzjfMmFOe #Trader #EXCHANGE #Ethereum #bitcoin  #myhedpay #cryptocurrency #B…', 'neg', 0.8571428571428571)
# ('another time traveller... what do you guys think? #BTC #Crypto', 'neg', 1.0)
# ('RT @Daman___: Bitcoin mafia is back to suppress the rising #bitcoin: https://t.co/zYUR440HTp', 'neg', 1.0)
# ('RT @exiledsurfer: earlier today @desantis previewed me @deosorg  his recursive, iterative OS running ONCHAIN. on BITCOIN. it will blow your…', 'neg', 1.0)
# ('RT @coinxes2: What makes COINXES the best Digital Exchange out there?\nGo to https://t.co/2lygYls22S for more info. \n#cryptocurrency #crypto…', 'neg', 0.7142857142857143)
# ('RT @JDKing007: #Waves #wavesplatform #web30 #blockchain #developers #bitcoin https://t.co/PFt6G2EsuC', 'neg', 1.0)
# ('RT @Crypto__AI: Pantera Leads $3.5 Million Round for Lightning-Powered SparkSwap DEX https://t.co/fV8gYsFbsm #Bitcoin #VentureCapital https…', 'neg', 1.0)
# ('The latest The Omnichanel™ Daily! https://t.co/0cnL5LWfZO #blockchain #bitcoin', 'neg', 1.0)
# ("#crypto today:\n\nMcap $181, 817B\nVolume $61, 701\n#btc dominance 50.7%\n\nBiggest gains #Ethereum 8.154%\n\n'Buy' Signal… https://t.co/B1siipwYPY", 'neg', 1.0)
# ('Get More Credit Now\nhttps://t.co/SuDic9E2YO #wsj #nytimes #reuters #jimmyfallon #chicago #weed #cannabis… https://t.co/ZP3xUn12j3', 'neg', 1.0)
# ('RT @dwparkinson: Buy Bitcoin\n\nIt’s the only protest you’ll ever need to take part in.\n\nIt’s also the most disruptive and effective protest…', 'pos', 1.0)
# ('Chinese Traders Pay Extra for Bitcoin Through OTC Desks Amid Crypto Market Surge https://t.co/F9g5y9f698 via @cointelegraph', 'neg', 1.0)
# ('#Crypto #NewsUpdate via #Bitcoin Mag: "Chinese Crypto Investors Return Strongly In Bitcoin: Did They Cause BTC Surg… https://t.co/ZhphfcehMR', 'neg', 1.0)
# ("RT @hizlibet: 💰💫#HIZLIBET'TEN ÇEVRİMSİZ BONUS YAĞMURU!\n\n💰💫#PAPARA İLE  20₺ YATIR! %25 #CEVRİMSİZ BONUS AL!\n\n💰💫#BITCOIN İLE  20₺ YATIR! %25…", 'neg', 1.0)
# ('Hedging #Bitcoin with other financial assets https://t.co/buSQm9p0mJ', 'neg', 1.0)
# ('#Crypto #NewsUpdate via #Bitcoin Mag: "Ambisafe Issues On-Chain Shares of a Fund Tracking Economic Interest in Spac… https://t.co/R2xwQdbu1m', 'neg', 1.0)
# ('Chinese Crypto Investors Return Strongly In Bitcoin: Did They Cause BTC Surge? | April 08, 2019 at 03:04PM | Visit:… https://t.co/7IpuwLU84P', 'neg', 1.0)
# ('Bitcoin $BTC Price: $5187.79 (0.65%)\nEthereum $ETH Price: $176.56 (5.16%)\nXRP $XRP Price: $0.35 (-1.88%)\nLitecoin… https://t.co/nJM5TtzTYG', 'neg', 1.0)
# ('Ambisafe Issues On-Chain Shares of a Fund Tracking Economic Interest in SpaceX | April 08, 2019 at 03:06PM | Visit:… https://t.co/5XWaDnKnZI', 'neg', 1.0)
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5a6c201b3d10> in <module>
#      27 auth.set_access_token(atoken, asecret)
#      28 twitterStream = Stream(auth, listener())
# ---> 29 twitterStream.filter(track=["bitcoin"])
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /opt/conda/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /opt/conda/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /opt/conda/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# /opt/conda/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# /opt/conda/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# /opt/conda/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# /opt/conda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0cd65f1f8801> in <module>
# ----> 1 all_data
#
# NameError: name 'all_data' is not defined
